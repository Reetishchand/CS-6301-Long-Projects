# %%
import matplotlib.pyplot as plt

size = [201,1001,50000,50001,1000000,1000000];
size_l = [1000000,4000000, 8000000,16000000,32000000,64000000,128000000,256000000];

my_xticks = ['','1K','50K','','','1M']
my_xticks_l = ['1M','','','16M','32M','64M','128M','256M']
my_yticks_l = ['100K','','','400K','500K','600K','700K', '800K']

time_ts = [9,13,97,119,1072,1272];
time_sl = [8,18,144,140,1562,1684];
time_rb = [8,14,161,204,2011,2251];

plt.figure(figsize=(10,8))
#plt.plot(size, time_ts, marker='^', linewidth=3, markersize=12, c='#679327', mfc='#cccc00')
plt.plot(size, time_ts, marker='^', linewidth=3, markersize=10, color = '#006666', mfc='#33CCCC')
plt.plot(size, time_sl, marker='D', linewidth=3, markersize=10, color = '#679327')
plt.plot(size, time_rb, marker='o', linewidth=3, markersize=10, c='black', mfc='#cc0000')
plt.xlabel('Input size', fontsize=16)
plt.ylabel('Run Time', fontsize=16)
plt.xticks(size,my_xticks,fontsize=12)
plt.legend(['Tree Set','Skip List','Red Black Tree'], fontsize=16)
print()
print()

time_ts = [390,1260,2444,4711,9002,18116,36096,75845];
time_sl = [1198,3847,6542,13789,25342,49408,99074,247233];
time_rb = [3187,10307,19697,38019,75543,150957,301165,727006];

plt.figure(figsize=(10,8))
plt.plot(size_l, time_ts, marker='^', linewidth=3, markersize=10, color = '#006666', mfc='#33CCCC')
plt.plot(size_l, time_sl, marker='D', linewidth=3, markersize=10, color = '#679327')
plt.plot(size_l, time_rb, marker='o', linewidth=3, markersize=10, c='black', mfc='#cc0000')
plt.xlabel('Input size', fontsize=16)
plt.ylabel('Run Time', fontsize=16)
plt.xticks(size_l,my_xticks_l,fontsize=12)
plt.yticks(time_rb,my_yticks_l,fontsize=12)
plt.legend(['Tree Set','Skip List','Red Black Tree'], fontsize=16)
print()
print()
